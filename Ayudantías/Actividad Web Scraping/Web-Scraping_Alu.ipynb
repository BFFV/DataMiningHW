# %% [markdown]
# Ayudantía Martes 28 de agosto de 2019

# %% [markdown]
# # Actividad Web Scraping
#
# ### Nombre: Benjamín Farías V.

# %% [markdown]
# ## Indicaciones generales :
#
# ### • En esta actividad deberan ocupar Web Scraping para obtener una base de datos a partir de los datos de bolsos en https://www.newchic.com/es/.
# ### •  Deben obtener los datos de 100 productos con los atributos de:
#     •  Nombre
#     •  Rating
#     •  Precio
#     •  Oferta
#     •  Puntos
#     •  Color
#     •  Envío
#     •  Especificación
#     •  Comentarios (obtener primeros 5)
#
# ### •  Para esta actividad se debe entregar Notebook y archivo CSV con la base de datos.
# ### • Entrega martes 27 de agosto a las 10:59 pm.

# %% [markdown]
# ## Elementos a usar para desarrollar esta actividad :
#
# • Usar find(), find all() y select(). Todos permiten la selección de tags. A continuación se muestra un ejemplo de estructura html:
#     - Tipo de tag
#         Ej. <a>, <div ...>
#     - Valores de atributos
#         Ej. <div class=”abclinksmain”>)
#     - N-ésimo hijo de/ Hermano de... <div class=”abclinksmain”>
#         <ul>
#         <li>—–Primer hijo de <ul> ...
#         </li>
#         <li>—–Segundo hijo de <ul>
#         <a href=”http://www. ...”>
#         A </a>
#         </li>
#         <li>—–Tercer hijo de <ul> ...
#         </li>
#         </u> </div>
#
# • Las funciones find() y find all() reciben como parámetro filtros para seleccionar tags. Por otra parte, select() acepta selectores CSS para el filtro. El modo de uso de ambos se indica en la documentación (*).
#     - Detalles de BeautifulSoup:
#          Para extraer el valor de un atributo de un tag deben usar tag[“atributo”].
#          Para acceder a su texto interior deben usar tag.text.
#
# • Obtener página de Inicio : Lo primero que deben hacer es obtener la data html de la página principal haciendo uso de la librería requests. Posteriormente, deben procesar su data a un objeto BeautifulSoup para poder navegar y buscar fácilmente a través del árbol.
#        - result = requests.get(path)
#        - content = result.content
#        - soup = BeautifulSoup(content, 'html.parser')
#
# • Obtener url directorios : Si bien en el lapso de tiempo de esta clase no se descargará toda la base de datos, es necesario poder hacer una navegación profunda del sitio.
#
# • Manejo de datos : Poner atención en el manejo de errores en casos en que algún atributo no exista. De no existir, rellenar con string o lista vacía ese atributo en la base de datos.
#
# ### (*) Para entender detalles de el uso de BeautifulSoup consultar la documentación https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# ## 1. Librerías

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Funciones para extraer información de los productos con los atributos que se señalan.

# %%
# Función que obtiene toda la información de los productos de la página
def get_products_info(url, results_list):
    content = requests.get(url)
    content.encoding = 'utf-8'
    soup = BeautifulSoup(content.text, "lxml")
    data = soup.find("ul", {"class": "clearfixes newlst_box product-list-js"}).find_all(
        "li", {"class": "wom_lst_detail product-item-js"})

    # Se itera sobre cada uno de ellos, obteniendo sus atributos en un diccionario
    for bag in data:
        product_url = bag.find("div", {"class": "wom_lst_pic product-image-js"}).find("a", href=True)['href']
        current_request = requests.get(product_url)
        current_request.encoding = 'utf-8'
        current = BeautifulSoup(current_request.text, "lxml")
        product = {}

        # Nombre
        name = current.find("h1", {"class": "d-inline product-info-product-name-js"}).text
        product["Name"] = name

        # Rating
        rating = current.find("div", {"class": "flex align-items-center mx-lg-n2 mt-lg-5"}).find("span").text
        product["Rating"] = float(rating[:3])

        # Precio
        price = current.find("span", {"class": "px-lg-2 price-number"})['data-sale-price']
        product["Price"] = float(price)

        # Oferta
        discount = current.find(
            "span", {"class": "px-lg-5 bg-primary text-white font-small product-price__discount product-price-discount-js"})[
            'data-discount']
        product["Discount (%)"] = int(discount)

        # Puntos (no se pueden obtener, ya que son dinámicos)
        points = current.find("li", {"class": "flex mx-lg-n2"})
        product["Points"] = points.find("div", {"class": "lg px-lg-2"}).text.strip()

        # Colores
        images = current.find_all(
            "div", {"class": "product-info__attr-image product-info-attr-image-js product-info-attr-image-ga-js"})
        colors = [x.find("img")['title'] for x in images]
        if not colors:
            colors = ['No Disponible!']
        product["Colors"] = ",".join(colors)

        # Envío
        shipping = current.find("div", {"class": "product-info-ship-msg-js"}).text
        product["Shipping"] = shipping

        # Especificaciones
        description = current.find("div", {"class": "product-description-container"})
        specs = description.find("span").text
        product["Specs"] = specs

        # Comentarios
        comments = current.find("div", {"class": "reviews-list mb-lg-50"})
        if not comments:
            comments = ['No hay comentarios!']
        else:
            comments = [x.text.strip() for x in comments.find_all("div", {"class": "mb-lg-20"}) if x.text.strip()]
        product["Comments"] = ",".join(comments)

        # Se añaden a la lista
        results_list.append(product)
    return

# %% [markdown]
# ## 3. Se extrae la información de varias páginas para obtener una mayor cantidad de productos.

# %%
# Se realiza la request a la página de los bolsos, separando la url para poder iterar sobre las distintas páginas 
# (en este caso son las primeras 3 páginas)

url_base = "https://es.newchic.com/bags-c-3579/"
url_extra = ".html?act=0&is_new=0&pagesize=35&sort=1&from=nav"

results = list()
for page in range(1, 4):
    new_url = f'{url_base}{page}{url_extra}'
    get_products_info(new_url, results)
results
# Out:
# [{'Name': 'Mujer Laptop de viaje de diseño Bolsa Crossbody sólido Bolsa  ',
#   'Rating': 5.0,
#   'Price': 36.99,
#   'Discount (%)': 75,
#   'Points': '',
#   'Colors': 'Rosado,Azul,Negro,Marrón,Burdeos',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,marrón,Rosado,Vino rojoEstilo: ViajarMaterial: PUTipo de patrón: Sólido',
#   'Comments': 'i love it,Fantastic quality ! Even fits my 13” laptop for work ! ❤️❤️❤️❤️❤️,Сумка очень понравилась! Вместительная, удобная. Качество отличное! Упаковано хорошо. Посылка пришла достаточно быстро. Спасибо продавцу!,muito linda, melhor do que eu esperava, e é bem grande.,I liked it very much Amazing bag with larger space'},
#  {'Name': 'QUEENIE Mujer Botella desmontable multifunción sólida Bolsa Hombro de compras Bolsa',
#   'Rating': 5.0,
#   'Price': 39.99,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Azul,Marrón,Burdeos,Negro,Rosado',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,marrón,Rosado,Vino rojoEstilo: Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: Cremallera,Aldaba,Cremallera y cerrojoOcasión: Fiesta,Versátil,tienda,ColegioTipo de patrón: Sólido,Decoración: SuaveForma: Totalizador,HombroEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremalleraDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'The order came without damages and was good packet. Also it was here really quick. The bag is a perfect size and not too big.,No me gusto mucho el forro de adentro pero la bolsa de afuera esta bonita,bonita y accesible,Beautiful Bag, very happy with my purchase,l’article est très bien.'},
#  {'Name': 'BRENICE Mochila vintage piel bovina',
#   'Rating': 4.9,
#   'Price': 39.98,
#   'Discount (%)': 52,
#   'Points': '',
#   'Colors': 'Café,Azul,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Mochila monocolor disponible en varios colores. Cierre mediante cremallera.Peso: 900 gLargo x alto x ancho 38,5 x 36 x 8,5 cm (15,16" x 14,17" x 3,35")Composición:Exterior: piel bovina',
#   'Comments': "A bolsa é linda, do tamanho da medida da foto e veio super bem embalada. Estou muito satisfeita.,Bella capiente una borsa da portare tutto i giorni.,Bella ..ne ho un'altra dello stesso modello di colore azzurro.. sono pratiche e di giusta dimensione,i like the color. its bluegray. worth the wait. bag is roomy, with sturdy handles. thank you,Love the bag, great size, good pockets, but was disappointed with the colour. I chose blue but the colour was closer to grey. Still for the price, it’s a great bag."},
#  {'Name': 'Mujer Tarjeta de cuero sintético sólido Bolsa Teléfono Bolsa Crossbody Bolsa',
#   'Rating': 5.0,
#   'Price': 19.99,
#   'Discount (%)': 60,
#   'Points': '',
#   'Colors': 'Burdeos,Azul,Rosa,Amarillo,Gris,Naranja,Negro',
#   'Shipping': 'solo queda 5 - enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,Amarillo,naranja,Rosa roja,Vino rojoEstilo: Viajar,Moda,Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,ColegioTipo de patrón: Sólido,Decoración: SuaveForma: HombroTipo de bolsa: Bolso del teléfonoEstructura de bolsas: Bolsillo del teléfono celular,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'No es tan expandible, es bastante rigida pero igual muy buen productor,نفس اللي بالصوره وجحمها مره عجبني,I was very pleased with this bag and have ordered two more for gifts.,good quality. love it.,Love the quality of the bag.. really nice.. especially the color'},
#  {'Name': 'Cartera de animal a lunares con cuerda',
#   'Rating': 5.0,
#   'Price': 5.99,
#   'Discount (%)': 74,
#   'Points': '',
#   'Colors': 'Negro,Rojo,Celeste,Gris,Violeta,Rosado,Verde',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Material:\xa0PU',
#   'Comments': "Took longer than expected to get here, but it's cute! The neck strap is a little long though, but that's okay,I like it,the product we all nice! fast delivery,really nice and arrived within time specified,Item came in good condition. Nice Colour."},
#  {'Name': 'Mujer National Bucket Bolsa Crossbody de impresión Bolsa',
#   'Rating': 4.8,
#   'Price': 11.66,
#   'Discount (%)': 58,
#   'Points': '',
#   'Colors': '# 01,# 02',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,BeigeEstilo: NacionalMaterial: LonaTipo de cierre: CuerdaOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: ImpresiónDecoración: CadenasForma: CangilónTipo de bolsa: Bolsa de canastaEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: M',
#   'Comments': 'This bag is absolutely beautiful. Everywhere I go with it, someone tells me how much they like it.,pretty sumner bag,Thank you ......................,just what I ordered,I really like this bag. Looks very beautiful & big enough for carrying a lot if things.'},
#  {'Name': 'QUEENIE Mujer Bolso en relieve informal Compras Hombro Bolsa',
#   'Rating': 5.0,
#   'Price': 39.99,
#   'Discount (%)': 58,
#   'Points': '',
#   'Colors': 'Black,Wine Red,Brown,Grey,Blue',
#   'Shipping': 'esperado enviado en February 07,2106',
#   'Specs': 'especificación :Color: Negro,Azul,rojo,marrón,GrisEstilo: NacionalMaterial: PUTipo de cierre: CremalleraOcasión: VersátilEstructura de bolsas: Bolsillo del teléfono celularCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carry',
#   'Comments': 'Arrived a day early...very good quality. In all delighted,Brilliant bag, cross body very comfy to wear and fits a lot more than you expect. Very well made and lovely colour.\r\nExcellent value for money, will be ordering more colours.,This bag is ideal for my needs. Can get all I need in it.,Very happy with my purchase Brilliant bag. Better than expected, very good quality & spacious. Just right for what I needed. Would recommend. ☺,Really pleased with quality of the leather ,love it'},
#  {'Name': 'Mujer Diseño Crossbody Multifunción Bolso Sólido Bolsa',
#   'Rating': 4.9,
#   'Price': 34.99,
#   'Discount (%)': 70,
#   'Points': '',
#   'Colors': 'Azul,Marrón,Rojo,Negro,Gris',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,rojo,marrón,GrisEstilo: Casual,MundanoMaterial: PUTipo de cierre: CremalleraOcasión: tiendaTipo de patrón: Forma: HombroEstructura de bolsas: Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: S',
#   'Comments': 'Great product. Look 95% like in the photos. Not as classy as in the photo though. I still really like the design with many small parts to put different things in this bag. Especially for the keychain holder, I love it very much.,The pockets are helpful. But it came distorted I had to do some fixing to get it in the shape atleast a little closer to the original. Cards can hardly fit in the slots. Still pretty though.,perfect,I liked the style of the bag and the color.,Nice bag!'},
#  {'Name': 'Mujer PU de cuero Embrague Bolsa Tarjeta Bolsa Teléfono Bolsa Crossbody Bolsa',
#   'Rating': 4.8,
#   'Price': 25.99,
#   'Discount (%)': 53,
#   'Points': '',
#   'Colors': 'Naranja,De color verde oscuro,Violeta,Azul,Gris,Negro,Burdeos,Rojo,Azul oscuro,Rojo 1',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,rojo,marrón,Gris,Rosado,Amarillo,Púrpura,naranja,Vino rojoEstilo: Viajar,Moda,Casual,MundanoMaterial: PUTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,Deporte,ColegioTipo de patrón: SólidoTipo de bolsa: Bolso del teléfonoEstructura de bolsas: Bolsillo del teléfono celular,Zipper_PouchDureza: DifícilCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'love the many mini compartments. makes it convenient.,The bag is nice and it has good quality. Worth the wait,the bag is nice but when i received the it. it was deformed and with stain. its nice if they put in in the box,this bag is too small. Smaller than appears in the pictures.,would be better if the bag was horizontal rather than vertical zippers'},
#  {'Name': 'Xiaomi Lecturer Backpack Bolsa',
#   'Rating': 0.0,
#   'Price': 26.99,
#   'Discount (%)': 72,
#   'Points': '',
#   'Colors': 'Black,Blue,White',
#   'Shipping': 'esperado enviado en Sep 03 - Sep 13',
#   'Specs': 'especificación :Color: Negro,Blanco,AzulEstilo: CasualMaterial: OxfordTipo de cierre: CremalleraOcasión: tienda,DeporteEstructura de bolsas: Bolsillo del teléfono celularCaracteristicas: Correas ajustables',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'Bolsos de viaje Bolsos lindos Nylon Bolsos Nylon Crossbody Bolsa Totalizador Bolsa',
#   'Rating': 4.8,
#   'Price': 15.99,
#   'Discount (%)': 68,
#   'Points': '',
#   'Colors': 'Elefante,Hoja,Árbol,Camuflaje,Leaf section,Raya,Leopardo marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: MulticolorEstilo: Negocio,bohemio,VendimiaMaterial: NylonTipo de cierre: CubrirOcasión: tienda,ColegioTipo de patrón: Floral,Leopardo,Animal Prints,A rayas,Hoja,Decoración: Puntadas,ArcoForma: Bostón,AtléticoTipo de bolsa: Bolso del teléfono,Bolsa de canastaEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Tenedor de cadena dominante interior,Compartimiento interiorCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: M',
#   'Comments': "It's really sweet, not sure if I will keep it for myself or give it as a gift. It's really quite unusual, well made and has lots of zipped pockets.,Cute bag...but hope it was a little more bigger. With several compartment to put stuff. Soft and silky material...light weight and with 3 useful way to carry. Actual bag us same as photo. Love it,I guess not so good.,parfait petit mes grande contenance"},
#  {'Name': 'Classic Business Mochilas 17L Capacidad Estudiantes Laptop Bolsa de Xiaomi MI JIA',
#   'Rating': 4.9,
#   'Price': 12.99,
#   'Discount (%)': 87,
#   'Points': '',
#   'Colors': 'Red,Black,Grey',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Estructura de bolsas: Compartimiento interior',
#   'Comments': 'Good as laptop bag,good quality. worth to purchase. Packing must be improved.,great material seems sturdy now, let’s see how long this will last,nice backpack, just what I was looking for.,Quality is very good, perfect for the notebook. USB port working I need a power bank.'},
#  {'Name': 'Impermeable Man al aire libre Puerto de carga USB para viaje Bolsa Sling casual Bolsa Cofre Bolsa ',
#   'Rating': 0.0,
#   'Price': 18.45,
#   'Discount (%)': 63,
#   'Points': '',
#   'Colors': 'Azul real,Gris,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,GrisEstilo: CasualMaterial: NylonTipo de cierre: CremalleraOcasión: VersátilForma: HombroTipo de bolsa: Bolsa de pechoEstructura de bolsas: Bolsillo interior de la ranuraCaracteristicas: Correas ajustables,Impermeabletamaño: S',
#   'Comments': 'Satisfeito com artigo.'},
#  {'Name': 'Original Xiaomi 10L Mochila 8 colores Nivel 4 Repelente al agua al aire libre Paquete para hombre Mujer',
#   'Rating': 5.0,
#   'Price': 6.99,
#   'Discount (%)': 78,
#   'Points': '',
#   'Colors': '\xa0Frontera azul,Rojo,Azul,Negro,Naranja,Amarillo,Verde,Rosado',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: MulticolorEstilo: CasualMaterial: Tipo de cierre: CremalleraOcasión: VersátilTipo de patrón: Decoración: SuaveEstructura de bolsas: Zipper_PouchCaracteristicas: Impermeabletamaño: L',
#   'Comments': 'Exactly what i want. And the price was just right. My only problem it took too long to come.,item received in gd condition. Not a big bag but gd ti use.,Nice colour, made well, really good price,a small backpack, excellent as a little handbag. big enough to get your iPad in.,I bought few, great quality.'},
#  {'Name': 'QUEENIE Mujer Casual Shopping Bolso multifunción hombro sólido Bolsa',
#   'Rating': 5.0,
#   'Price': 39.99,
#   'Discount (%)': 65,
#   'Points': '',
#   'Colors': 'Rosado,Caqui,Gris oscuro,Negro,Burdeos,Azul',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,Rosado,Caqui,Vino rojoEstilo: Moda,Casual,MundanoMaterial: PUTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,Deporte,ColegioTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Zipper_PouchDureza: DifícilCaracteristicas: Multi-Carrytamaño: M',
#   'Comments': 'super sac très grand comme sur la photo aucun défaut de fabrication vraiment super heureuse de mon achat !! je reviens très vite pour de nouvelles commandes,J’ai attendu 10 jours après l’avoir commander. Il est arrivé en très bon état ! Agréablement surprise !,Material is tough and stiff Very appealing Big enough to fit an arch file into 15 days to South Africa Pretoria Overall very happy,the perfect bag, very good quality and super comfortable, the pockets allow me to keep my bag organized and it’s perfect if you want it for school/university, also a large capacity. the shipping took a while but actually they warned me so I can’t complain, maybe about a month but considering I am from Argentina it’s understandable. I live my new bag and I really recommend you guys to get it, specially if you want it to go to uni <3 :),Nice bag, the quality is decent considering the price.'},
#  {'Name': 'Oxford Antirrobo Resistente al agua al aire libre Sling de viaje Bolsa Cofre Bolsa Crossbody Bolsa Para hombres',
#   'Rating': 5.0,
#   'Price': 14.9,
#   'Discount (%)': 50,
#   'Points': '',
#   'Colors': 'Negro,Azul',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,AzulEstilo: CasualMaterial: OxfordTipo de cierre: CremalleraOcasión: Versátil,ViajarTipo de bolsa: Bolsa de pechoEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchDureza: SuaveCaracteristicas: Resistente al agua,Multi-Carrytamaño: M',
#   'Comments': 'ordered the oxford travel sling bag so happy with the quality and excellent price looking forward to using it on holiday a must buy.,arrived in excellent condition. looks stylish and versatile. can’t wait to start carrying it around!,Perfecta. Ligera y se adapta bien al torso. Buena elección.,Awesome product nice and compact,nice product..worth the money'},
#  {'Name': 'QUEENIE Mujer Bolso de mano de hombro sólido para compras Bolsa',
#   'Rating': 4.5,
#   'Price': 41.99,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Brown,Red,Green,Black,Pink',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,marrón,Rosado,Verde,Vino rojoEstilo: Viajar,Moda,Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,Deporte,ColegioTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchDureza: SuaveCaracteristicas: Multi-Carrytamaño: M',
#   'Comments': "No me gusto el forro de adentro pero si esta bonita la bolsa de afuera, el forro lo deberían de hacer de una tela más suave,Really good product. Same as shown in images.,Color is a VERY orange brown not a light cool tone brown like I was hoping, HOWEVER! I’ve had it for almost two weeks and it’s survived a water bottle leaking, very well made!!! VERY happy!,Very great quality,i love the bag. it suits with every colour of clothes that I'm wearing"},
#  {'Name': 'Laides elegantes bolsos de cuero de la PU del remiendo sólido',
#   'Rating': 0.0,
#   'Price': 6.49,
#   'Discount (%)': 90,
#   'Points': '',
#   'Colors': 'Red,Black,Dark Grey,Pink,Brown',
#   'Shipping': 'esperado enviado en Sep 01',
#   'Specs': 'especificación :Color: MulticolorEstilo: Casual,damaMaterial: PUTipo de cierre: CubrirOcasión: tienda,ColegioTipo de patrón: SólidoForma: Hombrotamaño: M',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'Bolso de los hombres Mochila multifuncional informal sólido Crossbody Bolsa',
#   'Rating': 5.0,
#   'Price': 39.99,
#   'Discount (%)': 78,
#   'Points': '',
#   'Colors': 'Gris,Negro,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,marrón,GrisEstilo: Viajar,Moda,CasualMaterial: cuero de imitaciónTipo de cierre: Cremallera,Aldaba,Cremallera y cerrojoOcasión: Fiesta,Versátil,tienda,Viajar,ColegioForma: HombroMarca: EkpheroEstructura de bolsas: Bolsillo del teléfono celular,Zipper_PouchDureza: DifícilCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'I have been thinking for a long time, how to install this bag and finally research the same shape as the picture. My brother likes this package very much.,muchas gracias un producto perfecto e igual que las fotos y la descripción,El bolso es tal cual se describe. Imatación de piel buena. Suave al tacto. Y terminaciones correctas. Especial atención si lo quieren para llevar portatil. El mio es de 15.6" . Se adapta bien en el fondo del bolso pero cuesta meterlo porque la parte superior del bolso tiene una diferencia de un cm con la parte inferior por lo que el portatil entra con dificultad demasiado ajustado.,The item is very nice. My son will really love it.,Bag is worth the price and has a good look'},
#  {'Name': '4 UNIDS Mujer PU Bolso de Cuero Borla Ocio Crossbody Bolsa Hombro Sólido Bolsa',
#   'Rating': 4.4,
#   'Price': 11.43,
#   'Discount (%)': 55,
#   'Points': '',
#   'Colors': 'Marrón,Rojo,Gris,Verde,Azul,Negro,Gray1,Rosado',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,rojo,marrón,Gris,Rosado,VerdeEstilo: CasualMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoDecoración: BorlaEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontable,tamaño: M',
#   'Comments': 'chegou com menos tempo obrigada,The Quality its not that great, cheap from china.,taille plus petite qu’à quoi je m’attendais,Good for price paid,No muy buen material'},
#  {'Name': 'Mujer Multi-layer Casual Shoulder Bolsa Quilt Solid Handbag',
#   'Rating': 5.0,
#   'Price': 23.99,
#   'Discount (%)': 61,
#   'Points': '',
#   'Colors': 'Rojo,Caqui,Negro,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,rojo,marrón,CaquiEstilo: CasualMaterial: PU,cuero de imitaciónTipo de cierre: Cremallera y cerrojoOcasión: Fiesta,tienda,ViajarTipo de patrón: Forma: HombroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_Pouchtamaño: L',
#   'Comments': 'nice bag looks like the picture,Hermoso color y tamaño perfecto!,Хорошая вещь. Приятно удивлена таким качеством. Рекомендую,Thank you so much. Handbag is perfect and I absolutely love it.,the bag is good for day to day use and the material is good too.'},
#  {'Name': 'Cartera de cuero de microfibra con multi-ranuras de tarjeta para mujeres',
#   'Rating': 4.8,
#   'Price': 9.98,
#   'Discount (%)': 62,
#   'Points': '',
#   'Colors': 'Rojo,Azul oscuro,Negro,Rojo púrpura,Violeta,Café,Gris,Dorado,Rosado,Magenta',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: cartera Material: PU',
#   'Comments': 'I just love this Multi-Card Slots. They are very useful and they keep as knew for a long time. They occupy a small space in your bag. The best.,Awesome wallet. Looks great and works great,Seems okay. Looks like the photo. Hopefully it will provide room for all my cards so that I can find them easily.,love this so much. good quality and design,Nice, elegant and attractive'},
#  {'Name': 'Original Xiaomi 20L College Escuela 15.6 pulgadas Mochila para portátil ',
#   'Rating': 0.0,
#   'Price': 29.99,
#   'Discount (%)': 65,
#   'Points': '',
#   'Colors': 'Blue,Black,Grey',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,Azul,GrisEstilo: Viajar,Casual,MundanoMaterial: TejidosTipo de cierre: CremalleraOcasión: Viajar,ColegioTipo de bolsa: Bolso del ordenador portátilEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremallera,Zipper_Pouchtamaño: L',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'Mochila para mujer Bolso de viaje Mochila Escuela Hombro Bolsa',
#   'Rating': 4.8,
#   'Price': 27.54,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Marrón,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,marrónEstilo: VendimiaMaterial: PUTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoForma: CarteraEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustablestamaño: L',
#   'Comments': "Entrega com perfeição, produto de acordo com o que eu comprei adorei,really cute. I'm excited to use this!,Foi uma agradável surpresa a forma como tudo foi tratado. Já com a mochila pronta para a nova aventura. Obrigada,Llegó en buenas condiciones, recibí lo que esperaba. Bastante conforme para ser mi primera compra.,soo good. faster, best quality"},
#  {'Name': 'RFID Cartera antimagnética de cuero genuino de 11 colores con 11 ranuras de tarjeta',
#   'Rating': 4.9,
#   'Price': 9.98,
#   'Discount (%)': 69,
#   'Points': '',
#   'Colors': 'Rojo,Amarillo,Verde,Azul,Violeta,Negro,Magenta,Café,Rosado,Naranja,Marrón',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'Material: cuero genuino',
#   'Comments': "Качество хорошее,товар понравился спасибо,I love it!,Mignon mais trop petit pour carte d d'identité,Great wee wallet,Die Geldbörse ist perfekt. Größe und Farbe übereinstimmend, wie auf dem Foto zu sehen. Kunstleder"},
#  {'Name': 'Monedero para tarjeta de múltiples ranuras de color liso para hombres',
#   'Rating': 4.8,
#   'Price': 6.99,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Azul,Negro,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,marrónEstilo: Negocio,CasualTipo de cierre: Aldaba,CubrirOcasión: Versátil,ColegioTipo de bolsa: Titular de la tarjeta,MonederoTipo de carteras: Mini Carteras,Carteras de organizador,Monedero,Porta tarjetas,DelgadoEstilo de billetera: Broche de cierre',
#   'Comments': 'buen producto, llego en tiempo,nice.... oke.. good,Really great thing,Looks nice. I would recommend it to others.,جميلة جدا وخامتها روعة'},
#  {'Name': 'Bolso de Crossbody floral del cuero genuino de las mujeres Bolsos de Bohemia del bolso del cubo de la vendimia',
#   'Rating': 4.6,
#   'Price': 18.99,
#   'Discount (%)': 79,
#   'Points': '',
#   'Colors': 'No Disponible!',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: MulticolorEstilo: VendimiaMaterial: Piel genuinaTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de bolsa: Bolsa de canastaEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontable',
#   'Comments': "Bought this for my mother. It must have been stored for decades in some storage. It smells really bad. How could you ship something like that. It should be illegal.,un petit sac original,very nice and coloured bag!,Super contente, c'est exactement ce que j'attendais les couleurs, la qualité, le cuir, la forme ....,I really love this bag the shade of colour is darker than advertised but still a lovely bag thank you."},
#  {'Name': 'Gran capacidad Casual al aire libre Puerto USB de carga Puerto Sling Bolsa Cofre Bolsa Crossbody Bolsa',
#   'Rating': 4.9,
#   'Price': 14.86,
#   'Discount (%)': 51,
#   'Points': '',
#   'Colors': '01,02,03,04,05,06,07,08,09,10,11,12,13,14,15,dieciséis',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,marrón,Gris,Verde,PúrpuraEstilo: CasualMaterial: OxfordTipo de cierre: CremalleraOcasión: Versátil,ViajarTipo de bolsa: Bolsa de pechoEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Multi-Carrytamaño: M',
#   'Comments': 'Nice und as expected,Very nice bag,Eine Tolle Tasche elegant und praktisch,التأخير في التسليم,Practical bag. Good value. Smaller than I expected but like it.'},
#  {'Name': 'Mujer gran capacidad 2pcs bolsos de cuero de la PU Bolsa Crossbody Bolsa',
#   'Rating': 5.0,
#   'Price': 9.99,
#   'Discount (%)': 50,
#   'Points': '',
#   'Colors': 'Rosa 1,Marrón 1,Gris claro,Gris oscuro,Negro',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,marrón,Gris,RosadoEstilo: CasualMaterial: PU,cuero de imitaciónTipo de cierre: AldabaOcasión: VersátilTipo de patrón: Decoración: DifícilCaracteristicas: ',
#   'Comments': 'bem grande, gostei muito!'},
#  {'Name': 'Bolsos cruzados del viaje de la mochila bohemia de las mujeres del estampado forestal de las mujeres',
#   'Rating': 4.6,
#   'Price': 13.26,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Verde',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: VerdeEstilo: bohemioMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: ImpresiónForma: Cartera,HombroTipo de bolsa: Bolso del teléfonoEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremallera,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: S',
#   'Comments': 'poor product quality,the product was real,the bag is not like branded .,bonita, pero muy pequeña,es bonita pero pequeña'},
#  {'Name': '5/7/9 Bolsas de almacenaje impermeable',
#   'Rating': 5.0,
#   'Price': 12.99,
#   'Discount (%)': 78,
#   'Points': '',
#   'Colors': '#01,#03,#04,#02,#05,#07,#08,#09,#10,#06,#12,#13,#15,#11,#14',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Bolsa de almacenaje monocolor disponible en varios colores. Cierre mediante cremallera.',
#   'Comments': 'Beautiful and very useful luggage packing set. Fast delivery to Canada.,ADOREI! Lindo demais.,good product and received in perfect condition,perfect perfect perfect,perfecto, tal cual la foto'},
#  {'Name': "Mochila clásica de oxford adecuada para MacBook Pro de 11'' 13'' 15'' para hombres y mujeres",
#   'Rating': 4.7,
#   'Price': 26.35,
#   'Discount (%)': 46,
#   'Points': '',
#   'Colors': 'Negro,Gris,Rosa,Burdeos,Verde,Azul,Celeste',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: mochila',
#   'Comments': 'Adorei,recumendo Newchic a todos,obrigado pela atenção . Cumprimentos,Adorei estão de parabéns obrigado pela atenção Cumprimentos,Не совсем то, что ожидали, думали он из ткани снаружи и подкладка внутри, на самом деле из дешевой такой резиновой "ткани". Вместительный. Явно непромокаемый. Если его руками не трогать, то выглядит в общем стильно. Покупали ребенку в школу. Ребенок рад.,Demorou um pouco mais que o esperado, mas valeu a pena.,en perfecto estado muy lindo y de buen tamaño'},
#  {'Name': 'MANDY Mujer Bolso Cuadrado Sólido Casual De Compras Bolsa',
#   'Rating': 5.0,
#   'Price': 29.99,
#   'Discount (%)': 57,
#   'Points': '',
#   'Colors': 'Amarillo,Rojo,Gris,Rosado,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,rojo,Gris,Rosado,AmarilloEstilo: CasualMaterial: cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,ColegioTipo de patrón: Decoración: DifícilForma: HombroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Tenedor de cadena dominante interior,Zipper_PouchDureza: DifícilCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'tamanho e cor otimos,nice product and fast delivery,It is a good quality, but due to the transport, it has a little deformed on the side and I will have to waste a lot of time to mold it. The shoulder-strap is great and it stops to the taste of anyone even,Such a cute little bag!! I’ve been looking for a little yellow bag for ages and I’ve finally got one. It’s a really good size.,Very goooood quality'},
#  {'Name': 'Mochila de viaje antirrobo de nylon para mujeres Mochilas de hombro multifuncionales de ocio sólido',
#   'Rating': 4.9,
#   'Price': 19.68,
#   'Discount (%)': 55,
#   'Points': '',
#   'Colors': 'Negro,Caqui',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,CaquiEstilo: ViajarMaterial: NylonTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: L',
#   'Comments': 'Me encantó esta pequeña y portatil y el material parece bastante bueno,Bin sehr zufrieden und der Versand fing auch schnell. Tasche entspricht dem bild :) Kann ich weiter empfehlen,Well worth it for an every day bag.,Hola, las mochilas muy livianas y comodas, los huaraches super comodos y me los han halagado muchísimo, estoy contenta con estas compras, ojala las nuevas prendas que están por mandarme sean igual o mejor,exactly what I’m looking for'},
#  {'Name': 'Genuino cuero comercial casual bolsa pectoral al hombro en bandolera bolsa para hombres',
#   'Rating': 4.8,
#   'Price': 43.31,
#   'Discount (%)': 49,
#   'Points': '',
#   'Colors': 'Gris oscuro,Negro,Marrón,Amarillo marron',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Color: \xa0Marrón, negro, gris oscuro, amarillo marrón',
#   'Comments': "bag is very nice, more than nice for the price.,Bin sehr zufrieden, alles ist wie in der Beschreibung angegeben9p,Bought as a Father's Day gift. Attractive, nice quality. It got a little squished during transit because is was not stuffed with paper or boxed. My husband says he likes it. He has never worn anything like this before so we shall see if he uses it. It is masculine enough for a men's bag.,just beautiful and so comfortable,just perfect I love it"},
#  {'Name': 'Mujeres Nylon Resistente al agua Multi-slot Crossbody Bags Solid Leisure Shoulder Bags',
#   'Rating': 5.0,
#   'Price': 17.23,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Rosa roja,Burdeos,Violeta,Azul,Negro,Celeste,\xa0Cruz beige,Gris,Caqui,Gris plateado,Gris azul',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,Beige,Púrpura,Caqui,Rosa roja,Vino rojo,Cielo azulEstilo: ViajarMaterial: NylonTipo de cierre: CremalleraOcasión: tienda,ViajarTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustablestamaño: M',
#   'Comments': 'Very good product,lovely casual bag'},
#  {'Name': 'DREAME Mujer Bolso cosmético sólido Capacidad Bolso Crossbody bolsa multifunción',
#   'Rating': 4.9,
#   'Price': 39.99,
#   'Discount (%)': 67,
#   'Points': '',
#   'Colors': 'Rosa claro,Amarillo,Azul,Verde,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Rosado,Verde,AmarilloEstilo: Viajar,Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,Deporte,ColegioTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremallera,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'i love it! but smaller than i expected but still its a very cute bag. ❤️,جميلة جدا وشكرا,Comoda e capiente. Un must assoluto!,the strap is too long for me. really love the bag nonetheless!,prodotto perfetto. Anche pagando la spedizione venoce si rischia che arrivi con giorni di ritardo.'},
#  {'Name': 'Hombres Nylon Impermeable Crossbody de gran capacidad Bolsa Bolso para computadora de negocios multifunción',
#   'Rating': 4.7,
#   'Price': 27.99,
#   'Discount (%)': 71,
#   'Points': '',
#   'Colors': 'Gris,Negro,Azul,Caqui',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,CaquiEstilo: Viajar,NegocioMaterial: NylonTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de bolsa: Bolsa de mensajeroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Impermeable,Multi-Carrytamaño: L',
#   'Comments': "The bag has a lot of space, it can put a lot of things, and the grid is many, so practical.,Functional, better than expected quality; especially for the price. Many pockets, inside and out provide plenty of options to store your laptop,I bought the same gray, and the design won my heart. I have never found a package that can replace it.,Although it says 'men's', there is no reason whatsoever that it can't be used by a woman. We also need bags with lots of pockets to organize our lives! Especially on sale, this was a good buy. Also, it arrived quite quickly! Recommended!,High quality bad and I love the pockets around it"},
#  {'Name': 'Mujer PU cuero lindo leche Caja Crossbody Bolsa monedero del teléfono informal',
#   'Rating': 4.9,
#   'Price': 18.61,
#   'Discount (%)': 67,
#   'Points': '',
#   'Colors': 'Negro,Amarillo,Rojo,Azul,Rosado,Café,rojo amarillo,Azul amarillo,Amarillo + rosa,Café Amarillo,Azul rojo,Rosa rojo,Rojo y café,Azul rosado,Azul y café,Rosa y chocolate',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,rojo,Rosado,Amarillo,caféEstilo: Dibujos animadosMaterial: PU,cuero de imitaciónTipo de cierre: AldabaOcasión: Fiesta,Viajar,ColegioTipo de patrón: ImpresiónForma: CangilónTipo de bolsa: Bolsa de canastaCaracteristicas: Correas ajustablestamaño: M',
#   'Comments': 'really nice quality for the price and super unique purse. looks just like the photo on the website,I love the bag, but it came squashed not exactly formed like a milk carton. So I had to block it with news paper to get the carton shape back.,very cute, love the materials used,The bag is like the picture, however there were little spots tears and frays. I also do not,My friend loved it! A very cute and reasonable priced way to surprise her! It looks just like the pictures!'},
#  {'Name': 'Bolso cosmético del viaje del cordón de gran capacidad de las mujeres de nylon',
#   'Rating': 4.9,
#   'Price': 8.65,
#   'Discount (%)': 55,
#   'Points': '',
#   'Colors': 'Gris 1,grey2,Azul 1,Rosado,Gris,Azul,Negro,Rosa claro',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Azul,Gris,RosadoEstilo: Viajar,CasualMaterial: NylonTipo de cierre: CuerdaOcasión: Viajar,DeporteTipo de patrón: Impresión',
#   'Comments': 'صغيرة مقارنة بالصورة بس ممتازه,it looks fine, just need to pull drawstring.,exactly as advertised,very easy to use,Ad advertised inexpensive'},
#  {'Name': 'Bolso bandolera retro de PU con hasp Bolso de cubo para mujeres',
#   'Rating': 4.8,
#   'Price': 22.39,
#   'Discount (%)': 46,
#   'Points': '',
#   'Colors': 'Burdeos,Negro,Gris,Azul,Marrón,Rojo,Verde',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'Tipo: bolso bandolera Material: PU',
#   'Comments': 'Очень приятная на ощупь! В офис и на прогулку. Маленькая и благородная. Не смотрится вычурно, хоть и винтаж,Сумка понравилась,рекомендую продавца!,nice bags and good quality,I just love it,nice design for a bag'},
#  {'Name': 'Mujeres Hombres al Aire Libre Necesidad de Embarque Bolsa de Pasaporte Tarjetero de Mano Bolsa de Viaje',
#   'Rating': 5.0,
#   'Price': 10.79,
#   'Discount (%)': 45,
#   'Points': '',
#   'Colors': 'Azul,Magenta,Negro,Burdeos',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo del Artículo: Bolsa de Embarque Material: PU Cuero',
#   'Comments': 'Utile et pratique,great quality. i like it a lot,Es muy practico, yo lo lleve en mi viaje al extranjero. muy comodo y acceso rapido al Boarding Pass. Lo recomiendo,the quality doesnt worth the price,good product and received in perfect condition'},
#  {'Name': 'Mujer Ocio Mochila de viaje de gran capacidad Multifunción Soft Hombro de cuero Bolsa',
#   'Rating': 5.0,
#   'Price': 23.69,
#   'Discount (%)': 57,
#   'Points': '',
#   'Colors': 'Negro,Marrón',
#   'Shipping': 'esperado enviado en Sep 03',
#   'Specs': 'especificación :Color: Negro,marrónEstilo: ViajarMaterial: PUTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interiorCaracteristicas: Correas ajustables',
#   'Comments': 'amazing small bag for my weekend shopping love it,perfect choice .. loved it,love the design！,good quality... I like the color too...,Demorou mas chegou!'},
#  {'Name': 'Mujer Crossbody de franela sólida Bolsa Soft bolso de ocio ',
#   'Rating': 4.6,
#   'Price': 15.52,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Azul,Negro,Marrón,Gris',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,Azul,marrón,GrisEstilo: CasualMaterial: TerciopeloTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: M',
#   'Comments': 'Me gustó. Gracias,Nice purse, great color, just what I wanted.,Bella subito messa in dopera grazie,qualite moyenne trace de colle sur tissu et fermeture moyenne,nice bag,...but the bag strap is very thin...but so far is good, thank you seller'},
#  {'Name': 'Bolso hobo suave PU',
#   'Rating': 4.5,
#   'Price': 34.81,
#   'Discount (%)': 55,
#   'Points': '',
#   'Colors': 'Negro,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Bolso hobo monocolor en negro y marrón. Con correa ajustable. Cierre mediante cremallera.',
#   'Comments': 'bestone ,i liked it alot, perfectly as it is shown in pic,nice bag, but it smaller than i imagine the leather little bit bad smell but i can remove it by spray my parfume on there’s so many compartment so i can bring so many thing separately as i wish thankyou :),A bolsa é linda, zipers reforçados e o melhor: VÁRIOS COMPARTIMENTOS para ajudar na organização! Preço mais do que justo.,Good product, exactly as the picture shows,Gostei do produto só pensei q fosse maior.'},
#  {'Name': 'Viaje de negocios Bolsa Equipaje Bolsa Traje Aptitud Bolsa portátil de gran capacidad',
#   'Rating': 0.0,
#   'Price': 43.66,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Gris,Negro',
#   'Shipping': 'esperado enviado en Sep 06',
#   'Specs': 'especificación :Color: Negro,GrisEstilo: NegocioTipo de cierre: CremalleraOcasión: VersátilForma: HombroTipo de bolsa: Bolsa de lonaDureza: SuaveCaracteristicas: Correas ajustablestamaño: L',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'KVKY Bolso tote casual retro de lona de tres capas para mujeres',
#   'Rating': 4.6,
#   'Price': 30.0,
#   'Discount (%)': 57,
#   'Points': '',
#   'Colors': 'Azul,Negro,Gris,Café,Beige,Violeta',
#   'Shipping': 'esperado enviado en Sep 02',
#   'Specs': 'Marca: KVKY  Detalles: Tipo: bolso tote',
#   'Comments': 'good product,Liked. came exactly what I had ordered.,el pedido llego bien,مره شكرًا عجبني كثير كثير,A very good shoulder bag that i absolutely love. Would recommend!'},
#  {'Name': 'Pack de 6 bolsos de almacenamiento impermeable de nylón en viaje',
#   'Rating': 4.8,
#   'Price': 8.99,
#   'Discount (%)': 75,
#   'Points': '',
#   'Colors': 'Naranja,Burdeos,Gris,Negro,Verde,Celeste,Azul oscuro,Rosado,Azul,Sandía roja,Magenta',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: bolso de almacenamiento Material: nylón',
#   'Comments': "great product. I use it every time I travel. it’s really convenient to have everything organized in cubes!,way too small,Where is my second order ?,I don't use my bags for travel I use them to store my jewelry in. I put each piece of matching jewelry in a sandwich ziploc bag .. separate the gold from the silver and store in the bags accordingly. I do the same with my gold and silver earrings. When I need a piece of jewelry I just open the appropriate bag. Now I'm not spending my dress time trying to get them untangles.,Where is my second order ?how do I contact you about that ?"},
#  {'Name': 'FERRICOS RFID Cartera corta retra antimagnética de cuero genuino de gran capacidad para hombres',
#   'Rating': 4.8,
#   'Price': 28.53,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Marrón,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Material: cuero genuino',
#   'Comments': 'Very nice really liked it,Hello New Chic Customers! My Ferricos RFID Antimagnetic Genuine Leather Vintage Tri-fold Large Capacity Short Wallet For Men arrived yesterday and I was pleasantly surprised by its packaging and quality of Grade A leather material. Best wallet that I have ever owned and well worth the cost! I’m going to order another today! Jonathan Scales-Chicago,Authentic leather and good quality.,Все как на картинке, качество хорошое- рекомендую.,Thanks in very good order'},
#  {'Name': 'Bolso de depósito multifuncional de PU en ventilación de coche Bolso de móvil de chisme',
#   'Rating': 5.0,
#   'Price': 6.11,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Negro,Gris,Marrón,Beige',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': "Tipo: bolso de depósito de coche Color: crema, marrón, gris, negro Material: PU Peso: 80 g Largo: 8,5 cm (3,35'') Altura: 10 cm (3,94'') Ancho: 5 cm (1,97'') Patrón: sólido",
#   'Comments': 'E comodo ma poco resistente,Product is exactly as i saw it on website, really good fit,happy happy buyer,i love it,Very nice parcel, good for my cards.'},
#  {'Name': 'Para Mujeres de Viaje Neceser Portátil de Nylón Grande Cosmética Bolsa con Forro Organizador Ordenador Bolsa',
#   'Rating': 4.8,
#   'Price': 7.05,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Rojo,Amarillo,Gris,Verde,Violeta,Negro,Burdeos,Naranja,Rosado,Azul',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': "Tipo del Artículo: Cosmética Bolsa Color: Amarillo, Gris, Verde, Violeta, Negro, Vino Rojo, Naranja, Rosa, Azul Material: Nylón Peso: 100g Cinta: 5cm (1.97'') Longitud: 28cm (11.02'') Altura: 18cm (7.09'') Ancho: 9cm (3.54'') Patrón: Sólido Cierre: Cremallera",
#   'Comments': "This is now really small. It's a versatile product but expected it to be bigger. Love it overall.,Very handy to transfer things from bag to bag,This is a really nice liner for tote purses. I like not having to exchange all of my items from purse to purse now. Just one bag.,Genau wie auf dem Bild! Die Verarbeitung ist nicht perfekt aber für den Preis total in Ordnung.,petite sacoche très pratique,pour la vie quotidienne et les voyages"},
#  {'Name': 'Bolso bandolera deportivo ligero impermeable de nylón para mujeres',
#   'Rating': 4.9,
#   'Price': 16.49,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Magenta,Violeta,Negro,Azul,Burdeos',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': "Tipo: bolso bandolera Material:\xa0nylón \xa0 \xa0 \xa0\xa0Forro:\xa0poliéster Color: negro, violeta, magenta, azul, burdeos Dentro: bolsillo principal, bolsillo con cremallera, entrecapa, bolsillo de móvil, bolsillo de tarjeta Cierre: cremallera Grande Peso: 500 g Largo:\xa031 cm (12,20'') Alto:\xa024 cm (9,45'') Ancho:\xa015 cm (5,91'') Pequeño Peso: 400 g Largo:\xa025 cm (9,84'') Alto:\xa021 cm (8,27'') Ancho:\xa09,5 cm (3,74'')",
#   'Comments': "hermosa y práctica cartera, ya la estoy usando!,Todo perfecto....muy buen producto !,I SOOOOOO wanted to love this bag. It is roomy and functional but it STINKS. I am airing it for days now, indoors and outdoors but it still stinks. I am beginning to consider washing it...,Correspond à l'article commandée,esta super y con varios bolsillo muy utilitario"},
#  {'Name': 'Mujer Mochila de elefante nacional, PU, cuero, hombro Bolsa',
#   'Rating': 5.0,
#   'Price': 17.99,
#   'Discount (%)': 62,
#   'Points': '',
#   'Colors': 'Negro,Negro 1',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: NegroEstilo: NacionalMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: Animal PrintsDecoración: SuaveEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustables,Correa de hombro desmontabletamaño: L',
#   'Comments': 'es mas pequeño de lo que pense,love the bag. it is what I expected.,Суперудобный рюкзак, я в восторге!,Just as advertised in the catalogue. very happy with the product.,it came in a good condition and it looks just like the pictur . like it very much thank you'},
#  {'Name': '4 UNIDS Bolso Cubo Mujer Hombro Sencillo De Cuero De Imitación Bolsa Embrague Bolsa',
#   'Rating': 0.0,
#   'Price': 12.86,
#   'Discount (%)': 68,
#   'Points': '',
#   'Colors': 'Rojo,Gris,Negro,Rosa palido,Chocolate',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: MulticolorEstilo: CasualMaterial: PU,cuero de imitaciónOcasión: VersátilTipo de patrón: Tipo de bolsa: Bolsa de canastaDureza: DifícilCaracteristicas: ',
#   'Comments': 'é bonita, mas o acabamento é ruim, não tem forro. também é bem menor do que aparenta na foto'},
#  {'Name': 'Mujer Sólido Casual Sport Pequeño Crossbody Bolsa',
#   'Rating': 4.8,
#   'Price': 19.9,
#   'Discount (%)': 50,
#   'Points': '',
#   'Colors': 'Negro,Gris,Azul,Naranja,Verde,Rosado,Amarillo',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,Rosado,Verde,AmarilloEstilo: Viajar,Hip hop,Moda,Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,Viajar,Deporte,ColegioTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo interior con cremallera,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Multi-Carrytamaño: S',
#   'Comments': 'SUPER CUTE. AND GOOD QUALITY,Cute exactly as expected,very nice quality! you can match in any dress.. thumbs up!,Excellent value, excellent size, excellent colour, altogether excellent, this is the second colour I have bought.,I loved this bag'},
#  {'Name': 'Bolso bandolera bohemio estampado de gran capacidad',
#   'Rating': 4.8,
#   'Price': 25.45,
#   'Discount (%)': 59,
#   'Points': '',
#   'Colors': 'Verde,Rojo,Violeta',
#   'Shipping': 'esperado enviado en Aug 31',
#   'Specs': 'Material:\xa0PU',
#   'Comments': 'nice n good quality,Love this, I feel so smart and sassy when carrying it .,Me encantó, un poco pequeña pero me gustan pequeñas,جميله جدا,unique, cute and good material'},
#  {'Name': 'Cartera mona de dibujo animado Bolso de cuello con ranuras de tarjeta para mujeres',
#   'Rating': 4.8,
#   'Price': 8.99,
#   'Discount (%)': 45,
#   'Points': '',
# ...
#   'Comments': 'me deseciono es muy chico y el material con lo que está echo no me gustó,torebeczka jest śliczna,I received these bags. Several bags are very retro, I like them very much, and handbags can also be used as messenger bags and shoulder bags.,Juste un peu petit sinon très chouette,Good! The bag is very wearable.'},
#  {'Name': 'Mujer vendimia Bandolera de piel sintética Bolsa Cofre Bolsa Cintura Bolsa',
#   'Rating': 5.0,
#   'Price': 11.99,
#   'Discount (%)': 70,
#   'Points': '',
#   'Colors': 'blanco,Verde,Negro,Marrón,Burdeos,Café',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,Blanco,marrón,Verde,café,Vino rojoEstilo: Moda,Casual,Vendimia,Normcore / Minimalist,damaMaterial: PUTipo de cierre: CremalleraOcasión: Fiesta,Versátil,ViajarTipo de patrón: Sólido,Animal Prints,Decoración: DifícilForma: Hobos,Hombro,AtléticoTipo de bolsa: Bolsa de mensajero,CangureraEstructura de bolsas: Compartimiento interior,Zipper_PouchDureza: Difíciltamaño: M',
#   'Comments': 'Joli et apparence solide'},
#  {'Name': 'Cartera larga fina de PU con 15 bolsillos tarjeteros',
#   'Rating': 4.6,
#   'Price': 11.15,
#   'Discount (%)': 69,
#   'Points': '',
#   'Colors': 'Rojo,Violeta,Negro,Verde,Café,Naranja,Azul oscuro,Magenta,Amarillo',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': "Tipo: cartera Color: rojo, violeta, negro, verde, café, naranja, azul oscuro, rosa, amarillo Característica: fino, doble cremallera Material: PU Peso: 95 g Largo: 20 cm (7,87'') Altura: 11 cm (4,33'') Ancho: 1,5 cm (0,59'') Patrón: color puro Dentro: 15 bolsillos tarjeteros, bolsillo de móvil, bolsillo de dinero, bolsillo de foto Cierre: cremallera",
#   'Comments': 'I like how slim this purse is. the zip sections are a good size and lots of card room. I’m happy.,Love it going to order more .Good quality ,and holds more charge cards than regular slots a purse or wallet has. I now have two ,and going to order more for gifts.Awesome product,Favorite wallet for taking all my cc and quality made will recommend to everyone,the item was not as it appears though its not bad,The product is as per the description. The color mentioned in the site and the color recd is one and the same. The quality of the product is good and the switching is up to the mark.'},
#  {'Name': 'Cubierta para el polvo de la ropa Almacenamiento Bolsa Traje de ropa Vestido Ropa Abrigo bolsa de almacenamiento',
#   'Rating': 4.0,
#   'Price': 4.88,
#   'Discount (%)': 76,
#   'Points': '',
#   'Colors': 'Violeta,Purple-1833,Purple G13,Verde,Verde 2,Verde 3,Azul,Azul 2,Azul 3,Negro,Negro 2,Negro 3,Naranja,Orange 1602,Naranja 01,Magenta,Rosa 1,Rosa 2,Caqui,Kaki 2,Kaki 3,Burdeos,Vino Rojo 1,Vino rojo y blanco,Blanco crema,creamy-white,Cremoso',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,Blanco,Azul,Verde,naranja,Caqui,Vino rojoEstilo: CasualMaterial: OxfordTipo de cierre: CremalleraTipo de patrón: ',
#   'Comments': 'Nice medium weight bags. They should hold up fine for my purpose of storage.'},
#  {'Name': 'BULLCAPATAIN Bolso bandolera casual de cuero genuino Bolso pectoral de hombro para hombres',
#   'Rating': 4.9,
#   'Price': 42.84,
#   'Discount (%)': 53,
#   'Points': '',
#   'Colors': 'Amarillo marron,Café profundo,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Marca: BULLCAPTAIN Tipo: bolso bandolera Color: marrón, amarillo-marrón Material: cuero genuino Peso: 525 g',
#   'Comments': 'Exactly as described great bag,Absolutely love this shoulder bag. It is the perfect size.,correspond bien au descriptif pour mon mari ok,as was advertised,Color is different from delivered brown bag. Bag essentials are same and fits well although  disappointed colors are not distinguishing.'},
#  {'Name': 'Bolso bandolera de nylón en viaje para mujeres',
#   'Rating': 4.7,
#   'Price': 18.44,
#   'Discount (%)': 51,
#   'Points': '',
#   'Colors': 'Violeta,Azul,Rosa,Negro,Verde,Real,Rojo,Gris,Burdeos',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: bolso de viaje',
#   'Comments': 'I love having so many compartments to put things, plus all zipped up is a huge plus for me. Very well thought out!!!,Expected a better quality material with the price tag. But I had worn it. It’s a functional and practical bag. If only it was bigger.,Bag is okay,good enough for what I need in a trip,Отличная, практичная, легкая цвет очень приятный. Удобная сумка.'},
#  {'Name': 'Mujer Soporte de tarjeta cuadrado Teléfono Bolsa Crossbody de múltiples capas Bolsa',
#   'Rating': 4.4,
#   'Price': 15.99,
#   'Discount (%)': 75,
#   'Points': '',
#   'Colors': 'Amarillo,Rojo,Negro,Azul,Marrón',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,Azul,rojo,marrón,AmarilloEstilo: Moda,Casual,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: Cremallera,Aldaba,Cremallera y cerrojoOcasión: Fiesta,Versátil,tienda,Viajar,ColegioTipo de patrón: SólidoForma: HombroTipo de bolsa: Bolso del teléfonoEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremallera,Zipper_PouchDureza: DifícilCaracteristicas: Correas ajustables,Correa de hombro desmontable,Multi-Carrytamaño: M',
#   'Comments': 'It looks different from the photo. It is much smaller and the rope is very short ... I am not satisfied at all. It is very expensive for the quality of the product.,This bag is a great little bag. It has enough room to carry exactly what you need, is a lightweight bag and it appears well made.,Great bag with lots of compartments. Quality is good too.,Sooo Love it,Cute Bag! Love it very much.'},
#  {'Name': 'KVKY Bolsos de lona a rayas Bolsos de crossbody de contraste de color vintage',
#   'Rating': 5.0,
#   'Price': 29.75,
#   'Discount (%)': 53,
#   'Points': '',
#   'Colors': 'Marrón',
#   'Shipping': 'esperado enviado en Sep 03',
#   'Specs': 'especificación :Color: marrónEstilo: Viajar,Casual,Vendimia,Normcore / MinimalistMaterial: LonaTipo de cierre: CremalleraOcasión: tienda,Viajar,Deporte,ColegioTipo de patrón: Sólido,A rayasDecoración: HardwareForma: TotalizadorEstructura de bolsas: Bolsillo del teléfono celular,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Multi-Carrytamaño: L',
#   'Comments': 'Love, love, love the bag. Matches all my outfits,This is a great bag. The quality is as good as expected. Am very pleased with this purchase.,good spacious bag,This bag is very well made, takes a lot of weight, perfect for work and as an overnight bag, have had lots of compliments about it too - recommended.,Beautiful, spacey handbags!!'},
#  {'Name': 'Bullcaptain cuero genuino Business Messenger Bag Vintage Crossbody bolsa para hombres',
#   'Rating': 4.9,
#   'Price': 35.92,
#   'Discount (%)': 46,
#   'Points': '',
#   'Colors': 'Negro,Marrón,Amarillo marron,Café',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'especificación :Color: Negro,marrón,AmarilloEstilo: Negocio,VendimiaMaterial: Piel genuina,Cuero de vacaTipo de cierre: Cremallera y cerrojoOcasión: Fiesta,ViajarTipo de bolsa: Bolsa de mensajero,Bolso del negocioMarca: Nullcaptain',
#   'Comments': 'love it !,Produit conforme à sa description et apparemment de bonne qualité! Sac pratique et bien conçu! Bien emballé! Je suis très satisfait de cet achat, mais des efforts restent à accomplir dans les délais de livraison! Commandé le 17 octobre et livré ce 5 décembre!,Got this as a gift for my wonderful wife and she is so very happy with this bag,Produto de boa qualidade, estou satisfeito.,Looks good, is firmly made. There’s enough compartments.'},
#  {'Name': 'Mujer Claro Láser Hombro Bolsa Cadenas Elegante Mini Crossbody de PVC Bolsa',
#   'Rating': 0.0,
#   'Price': 7.99,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Plateado,Azul,Rosa 1',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Azul,Rosado,PlataEstilo: ModaMaterial: Tipo de cierre: CubrirOcasión: VersátilTipo de patrón: sombraDecoración: Forma: HombroDureza: DifícilCaracteristicas: reflexivotamaño: S',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'Bolsa de almacenaje para maquillajes en viaje',
#   'Rating': 4.8,
#   'Price': 8.85,
#   'Discount (%)': 46,
#   'Points': '',
#   'Colors': 'Azul,Rosado,Burdeos,Azul marino',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: bolsa de almacenaje',
#   'Comments': "sembra più grande e di miglior qualità in foto!!,Très pratique. J'adore !,Расцветка серая. на фотографии ярче .,Es como se muestra en la foto, aunque el color es un poco mas opaco de lo que se ve en la foto. Un estuche practico y bonito para viajar con todos tus cosmeticos arreglados, pero quizas no sea muy resistente, asi que recomiendo no llenarlo demasiado de cosas para no romper el gancho de colgar.,Esta muy bonita y practica gracias."},
#  {'Name': 'Mujer Mini bandolera casual liso Bolsa ',
#   'Rating': 0.0,
#   'Price': 8.88,
#   'Discount (%)': 48,
#   'Points': '',
#   'Colors': 'Red,Black,Gray,Pink,Brown',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,rojo,marrón,Gris,RosadoEstilo: CasualMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: VersátilTipo de patrón: Decoración: DifícilForma: HombroDureza: DifícilCaracteristicas: Correas ajustablestamaño: S',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'Bolso bandolera casual de lona Bolso tote de grande capacidad para mujeres',
#   'Rating': 4.8,
#   'Price': 24.18,
#   'Discount (%)': 56,
#   'Points': '',
#   'Colors': 'Violeta,Marrón,Beige,Gris,Azul',
#   'Shipping': 'esperado enviado en Sep 03',
#   'Specs': 'Material: lona',
#   'Comments': 'same as picture! Nice purchase!,quality is good,nice.. but bigger than  I thought.  I like it,muy bonito y comodo,super nice and elegant'},
#  {'Name': 'BRENICE Cartera larga RFID piel bovina',
#   'Rating': 4.8,
#   'Price': 35.03,
#   'Discount (%)': 41,
#   'Points': '',
#   'Colors': 'Azul,Violeta,Rojo,Negro',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Cartera larga monocolor disponible en varios colores. Cierre mediante cremallera y broche.Peso: 200 gLargo x alto x ancho 20 x 11,5 x 2 cm (7,87" x 4,53" x 0,79")Composición:Exterior: piel bovina',
#   'Comments': "actual item seemed different from seller's photos. outer and inner materials are different and in color too. nice that the wallet is bigger than usual wallets.,I loved the product..,card pockets are small,Very nice wallet, glad I purchased it.,very useful purse, lots of pockets and storage"},
#  {'Name': 'Bolso bandolera pequeño irregular para móvil',
#   'Rating': 4.9,
#   'Price': 5.99,
#   'Discount (%)': 63,
#   'Points': '',
#   'Colors': 'Rojo,Café,Burdeos,Violeta,Verde,Negro,Naranja',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Tipo: bolso bandolera Material: PU',
#   'Comments': 'Sac étroit parfait pour mettre peu de choses très pratique léger pour l’ été sympa bonne qualité,excellent bag for phone and feel personals,Excelente producto y calidad y tamaño,great product - took to Europe!,Très sympathique correspond bien à limage'},
#  {'Name': 'Bolso de hombro impermeable de la bolsa de hombro de gran capacidad del bolso de la momia de las mujeres',
#   'Rating': 5.0,
#   'Price': 24.72,
#   'Discount (%)': 62,
#   'Points': '',
#   'Colors': 'Violeta,Rojo,Azul,Negro,Púrpura 1,Rojo 1,Azul 1,Negro 1,Púrpura 2,rojo 2,Azul 2,Negro 2',
#   'Shipping': 'esperado enviado en Aug 31',
#   'Specs': 'especificación :Color: Negro,Azul,Púrpura,Rosa rojaEstilo: ViajarMaterial: NylonTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoForma: HombroTipo de bolsa: Bolsa de mensajeroEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchCaracteristicas: Correas ajustablestamaño: L,M,S',
#   'Comments': 'i LOVE this bag!!!!! its my 4th bag i am hoarding. its PERFECT. i couldnt sleep waiting for this bag!! its my second time to re-order. i did expidited delivery and it took only 8days Flat. Quality is GREAT. i am soooooo happy thank you!!!!,Delivered without any problem in time.,chegou dentro do prazo. maravilha, voltarei a fazer nova compra.,Adorei o produto.,Great bag. Big enough for everyday use.'},
#  {'Name': 'Tarjetero de cuero genuino con cremallera y 20/40/60 ranuras de tarjeta',
#   'Rating': 5.0,
#   'Price': 17.21,
#   'Discount (%)': 57,
#   'Points': '',
#   'Colors': 'Rosa oscuro,Rosado,Azul,Violeta,Rosa,Negro,01,02,03,04,05,06,07,08,09,10,11,12',
#   'Shipping': 'en stock, enviado en Aug 28 - Aug 30',
#   'Specs': 'Material: cuero genuino',
#   'Comments': "Happy with the item, what you see is what you get. But delivery is so disappointing!,This holds all my cards, cash and coupons. I've had it for a month now I think and it's still good. I would recommend this wallet.,This wallet is amazing! I have a holder for every credit card and still enough space for more randomness! This is the next purchase I have made in a while.,love the color and tassle and the card slots were just what I needed,comfortable to use all my cards fit perfectly"},
#  {'Name': 'Caja multifuncional del teléfono de la cartera del vintage para iPhone6 \u200b\u200b/ 6 Plus / 6s / 6s Plus / 7 / 7Plus / 8/8 Plus / X',
#   'Rating': 0.0,
#   'Price': 19.98,
#   'Discount (%)': 54,
#   'Points': '',
#   'Colors': 'Marrón,Burdeos,Verde',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: marrón,Verde,Vino rojoEstilo: Casual,VendimiaMaterial: PUTipo de cierre: AldabaTipo de bolsa: Bolso del teléfono,Titular de la tarjetaTipo de carteras: Soporte para teléfonoEstilo de billetera: Cremallera',
#   'Comments': 'No hay comentarios!'},
#  {'Name': 'vendimia Hombro de borla Bolsa Hombro Bolsa Para Mujer',
#   'Rating': 4.7,
#   'Price': 34.11,
#   'Discount (%)': 43,
#   'Points': '',
#   'Colors': 'Rojo,Marrón,Negro,Rosado,Verde,Beige',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,rojo,marrón,Rosado,Verde,BeigeEstilo: Viajar,Moda,Nacional,Casual,bohemio,Vendimia,MundanoMaterial: PU,cuero de imitaciónTipo de cierre: CremalleraOcasión: Fiesta,Versátil,tienda,ViajarTipo de patrón: SólidoDecoración: BorlaForma: Cangilón,Hobos,Saffiano,Pandora,Cáscara,Bostón,HombroTipo de bolsa: Bolsa de mensajero,Bolsa de retención,Bolsa de canastaEstructura de bolsas: Bolsillo interior de la ranura,Bolsillo del teléfono celular,Bolsillo interior con cremallera,Compartimiento interior,Zipper_PouchDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable,Impermeable,Multi-Carrytamaño: M',
#   'Comments': "I am much surprised by the quality of the product. Honestly, it's every penny. Thanks guys,اللون غير مطابق الصوره تماما اختلاف بسيط,качество"},
#  {'Name': 'Bolso cruzado sólido del teléfono de las mujeres multi-ranura impermeable impermeables de nylon mini del bolso',
#   'Rating': 4.7,
#   'Price': 13.59,
#   'Discount (%)': 59,
#   'Points': '',
#   'Colors': 'Burdeos,Violeta,Caqui,Verde,Azul,Negro,Gris',
#   'Shipping': 'esperado enviado en Aug 30 - Sep 01',
#   'Specs': 'especificación :Color: Negro,Azul,Gris,Verde,Púrpura,Caqui,Vino rojoEstilo: ViajarMaterial: NylonTipo de cierre: CremalleraOcasión: Fiesta,tienda,Viajar,ColegioTipo de patrón: SólidoForma: HombroEstructura de bolsas: Bolsillo del teléfono celular,Bolsillo interior con cremalleraDureza: SuaveCaracteristicas: Correas ajustables,Correa de hombro desmontable',
#   'Comments': 'just like the picture, nice bag.,Very handy for travelling to put passports & cell phones. Quality is nylon so it is also waterprove.,very cute and of good quality,me encantó mi carter,simple and recommended'}]

# %% [markdown]
# ## 4. Cargar base de datos en un dataframe y almacenar en un archivo con extensión CSV.

# %%
# Se cargan los datos a un DataFrame
data = pd.DataFrame(results)
data
# Out:
#                                                   Name  Rating  Price  \
# 0    Mujer Laptop de viaje de diseño Bolsa Crossbod...     5.0  36.99
# 1    QUEENIE Mujer Botella desmontable multifunción...     5.0  39.99
# 2                  BRENICE Mochila vintage piel bovina     4.9  39.98
# 3    Mujer Tarjeta de cuero sintético sólido Bolsa ...     5.0  19.99
# 4               Cartera de animal a lunares con cuerda     5.0   5.99
# ..                                                 ...     ...    ...
# 100  Bolso de hombro impermeable de la bolsa de hom...     5.0  24.72
# 101  Tarjetero de cuero genuino con cremallera y 20...     5.0  17.21
# 102  Caja multifuncional del teléfono de la cartera...     0.0  19.98
# 103  vendimia Hombro de borla Bolsa Hombro Bolsa Pa...     4.7  34.11
# 104  Bolso cruzado sólido del teléfono de las mujer...     4.7  13.59
#
#      Discount (%) Points                                             Colors  \
# 0              75                          Rosado,Azul,Negro,Marrón,Burdeos
# 1              56                          Azul,Marrón,Burdeos,Negro,Rosado
# 2              52                                          Café,Azul,Marrón
# 3              60             Burdeos,Azul,Rosa,Amarillo,Gris,Naranja,Negro
# 4              74              Negro,Rojo,Celeste,Gris,Violeta,Rosado,Verde
# ..            ...    ...                                                ...
# 100            62         Violeta,Rojo,Azul,Negro,Púrpura 1,Rojo 1,Azul ...
# 101            57         Rosa oscuro,Rosado,Azul,Violeta,Rosa,Negro,01,...
# 102            54                                      Marrón,Burdeos,Verde
# 103            43                      Rojo,Marrón,Negro,Rosado,Verde,Beige
# 104            59               Burdeos,Violeta,Caqui,Verde,Azul,Negro,Gris
#
#                                       Shipping  \
# 0         en stock, enviado en Aug 28 - Aug 30
# 1         en stock, enviado en Aug 28 - Aug 30
# 2         en stock, enviado en Aug 28 - Aug 30
# 3    solo queda 5 - enviado en Aug 28 - Aug 30
# 4         en stock, enviado en Aug 28 - Aug 30
# ..                                         ...
# 100                 esperado enviado en Aug 31
# 101       en stock, enviado en Aug 28 - Aug 30
# 102        esperado enviado en Aug 30 - Sep 01
# 103        esperado enviado en Aug 30 - Sep 01
# 104        esperado enviado en Aug 30 - Sep 01
#
#                                                  Specs  \
# 0    especificación :Color: Negro,Azul,marrón,Rosad...
# 1    especificación :Color: Negro,Azul,marrón,Rosad...
# 2    Mochila monocolor disponible en varios colores...
# 3    especificación :Color: Negro,Azul,Gris,Amarill...
# 4                                         Material: PU
# ..                                                 ...
# 100  especificación :Color: Negro,Azul,Púrpura,Rosa...
# 101                            Material: cuero genuino
# 102  especificación :Color: marrón,Verde,Vino rojoE...
# 103  especificación :Color: Negro,rojo,marrón,Rosad...
# 104  especificación :Color: Negro,Azul,Gris,Verde,P...
#
#                                               Comments
# 0    i love it,Fantastic quality ! Even fits my 13”...
# 1    The order came without damages and was good pa...
# 2    A bolsa é linda, do tamanho da medida da foto ...
# 3    No es tan expandible, es bastante rigida pero ...
# 4    Took longer than expected to get here, but it'...
# ..                                                 ...
# 100  i LOVE this bag!!!!! its my 4th bag i am hoard...
# 101  Happy with the item, what you see is what you ...
# 102                                No hay comentarios!
# 103  I am much surprised by the quality of the prod...
# 104  just like the picture, nice bag.,Very handy fo...
#
# [105 rows x 9 columns]

# %%
# Se guarda la información obtenida en un archivo .csv
with open("newchicBolsos.csv", "w", encoding="utf-8") as db:
    data.to_csv(db, sep=';', index=False, encoding='utf-8')

# %%
# Ahora podemos utilizarlo para analizar la información!
df = pd.read_csv("newchicBolsos.csv",  sep=';')
df
# Out:
#                                                   Name  Rating  Price  \
# 0    Mujer Laptop de viaje de diseño Bolsa Crossbod...     5.0  36.99
# 1    QUEENIE Mujer Botella desmontable multifunción...     5.0  39.99
# 2                  BRENICE Mochila vintage piel bovina     4.9  39.98
# 3    Mujer Tarjeta de cuero sintético sólido Bolsa ...     5.0  19.99
# 4               Cartera de animal a lunares con cuerda     5.0   5.99
# ..                                                 ...     ...    ...
# 100  Bolso de hombro impermeable de la bolsa de hom...     5.0  24.72
# 101  Tarjetero de cuero genuino con cremallera y 20...     5.0  17.21
# 102  Caja multifuncional del teléfono de la cartera...     0.0  19.98
# 103  vendimia Hombro de borla Bolsa Hombro Bolsa Pa...     4.7  34.11
# 104  Bolso cruzado sólido del teléfono de las mujer...     4.7  13.59
#
#      Discount (%)  Points                                             Colors  \
# 0              75     NaN                   Rosado,Azul,Negro,Marrón,Burdeos
# 1              56     NaN                   Azul,Marrón,Burdeos,Negro,Rosado
# 2              52     NaN                                   Café,Azul,Marrón
# 3              60     NaN      Burdeos,Azul,Rosa,Amarillo,Gris,Naranja,Negro
# 4              74     NaN       Negro,Rojo,Celeste,Gris,Violeta,Rosado,Verde
# ..            ...     ...                                                ...
# 100            62     NaN  Violeta,Rojo,Azul,Negro,Púrpura 1,Rojo 1,Azul ...
# 101            57     NaN  Rosa oscuro,Rosado,Azul,Violeta,Rosa,Negro,01,...
# 102            54     NaN                               Marrón,Burdeos,Verde
# 103            43     NaN               Rojo,Marrón,Negro,Rosado,Verde,Beige
# 104            59     NaN        Burdeos,Violeta,Caqui,Verde,Azul,Negro,Gris
#
#                                       Shipping  \
# 0         en stock, enviado en Aug 28 - Aug 30
# 1         en stock, enviado en Aug 28 - Aug 30
# 2         en stock, enviado en Aug 28 - Aug 30
# 3    solo queda 5 - enviado en Aug 28 - Aug 30
# 4         en stock, enviado en Aug 28 - Aug 30
# ..                                         ...
# 100                 esperado enviado en Aug 31
# 101       en stock, enviado en Aug 28 - Aug 30
# 102        esperado enviado en Aug 30 - Sep 01
# 103        esperado enviado en Aug 30 - Sep 01
# 104        esperado enviado en Aug 30 - Sep 01
#
#                                                  Specs  \
# 0    especificación :Color: Negro,Azul,marrón,Rosad...
# 1    especificación :Color: Negro,Azul,marrón,Rosad...
# 2    Mochila monocolor disponible en varios colores...
# 3    especificación :Color: Negro,Azul,Gris,Amarill...
# 4                                         Material: PU
# ..                                                 ...
# 100  especificación :Color: Negro,Azul,Púrpura,Rosa...
# 101                            Material: cuero genuino
# 102  especificación :Color: marrón,Verde,Vino rojoE...
# 103  especificación :Color: Negro,rojo,marrón,Rosad...
# 104  especificación :Color: Negro,Azul,Gris,Verde,P...
#
#                                               Comments
# 0    i love it,Fantastic quality ! Even fits my 13”...
# 1    The order came without damages and was good pa...
# 2    A bolsa é linda, do tamanho da medida da foto ...
# 3    No es tan expandible, es bastante rigida pero ...
# 4    Took longer than expected to get here, but it'...
# ..                                                 ...
# 100  i LOVE this bag!!!!! its my 4th bag i am hoard...
# 101  Happy with the item, what you see is what you ...
# 102                                No hay comentarios!
# 103  I am much surprised by the quality of the prod...
# 104  just like the picture, nice bag.,Very handy fo...
#
# [105 rows x 9 columns]
